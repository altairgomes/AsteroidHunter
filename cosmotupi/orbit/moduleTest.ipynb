# %%
from datetime import datetime, timezone
from determine_orbit import determine_orbit

observations_apophis = [
   {"RA": 61.533666, "DEC": 16.917944, "timestamp": datetime(2004, 3, 15, 2, 35, 21, 696000, tzinfo=timezone.utc)},
   {"RA": 61.548958, "DEC": 16.920972, "timestamp": datetime(2004, 3, 15, 2, 58, 4, 320000, tzinfo=timezone.utc)},
   {"RA": 61.562083, "DEC": 16.923722, "timestamp": datetime(2004, 3, 15, 3, 17, 34, 272000, tzinfo=timezone.utc)},
   {"RA": 61.564917, "DEC": 16.925194, "timestamp": datetime(2004, 3, 15, 3, 21, 58, 848000, tzinfo=timezone.utc)},
]

observations_dz2 = [
   {"RA": 123.942792, "DEC": 19.404944, "timestamp": datetime(2023, 2, 11, 5, 30, 11, tzinfo=timezone.utc)},
   {"RA": 123.941458, "DEC": 19.405278, "timestamp": datetime(2023, 2, 11, 5, 37, 35, tzinfo=timezone.utc)},
   {"RA": 123.940125, "DEC": 19.405472, "timestamp": datetime(2023, 2, 11, 5, 45, 1, tzinfo=timezone.utc)},
   {"RA": 123.938792, "DEC": 19.405667, "timestamp": datetime(2023, 2, 11, 5, 52, 27, tzinfo=timezone.utc)},
]

# %%
a, e, i, Omega, omega, theta, r_final, v_final, rms_residuo = determine_orbit("2023 DZ2", observations_dz2)

a_real = 2.082
e_real = 0.5242
i_real = 0.15
print("\nComparação com elementos reais (2023 DZ2):")
print(f"a real ≈ {a_real:.4f} UA, diferença: {abs(a - a_real):.4f} UA")
print(f"e real ≈ {e_real:.4f}, diferença: {abs(e - e_real):.4f}")
print(f"i real ≈ {i_real:.2f}°, diferença: {abs(i - i_real):.2f}°")
# Out:
# ===================================================
#
# CALCULANDO ÓRBITA DE 2023 DZ2 USANDO 4 OBSERVAÇÕES
# ===================================================
#
#
# ▶ INICIANDO CORREÇÃO DIFERENCIAL
# ────────────────────────────────
#
# INFO - [models.orbit_determiner] -  Iteração 1:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: 28538.7019, 28542.0916, 28549.0006 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.000235 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 1.8970 UA, e = 0.1762, i = 1.0804°
# INFO - [core.gauss_iod] -  Velocidade orbital: 21.0 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=1.893169 AU, e=0.188252, i=23.853914°
# INFO - [models.orbit_determiner] -  Δρ = 0.000054 AU
#
# INFO - [models.orbit_determiner] -  Iteração 2:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: 28538.2974, 28541.6870, 28548.5959 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.000235 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 1.8970 UA, e = 0.1762, i = 1.0805°
# INFO - [core.gauss_iod] -  Velocidade orbital: 21.0 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=1.893142 AU, e=0.188519, i=23.854002°
# INFO - [models.orbit_determiner] -  Δρ = 0.000006 AU
#
# INFO - [models.orbit_determiner] -  Iteração 3:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: 28536.4584, 28539.8477, 28546.7562 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.000235 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 1.8970 UA, e = 0.1762, i = 1.0805°
# INFO - [core.gauss_iod] -  Velocidade orbital: 21.0 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=1.893146 AU, e=0.188748, i=23.854050°
# INFO - [models.orbit_determiner] -  Δρ = 0.000011 AU
#
# INFO - [models.orbit_determiner] -  Iteração 4:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: 28539.8175, 28543.2073, 28550.1165 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.000235 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 1.8970 UA, e = 0.1762, i = 1.0805°
# INFO - [core.gauss_iod] -  Velocidade orbital: 21.0 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=1.893132 AU, e=0.188330, i=23.853956°
# INFO - [models.orbit_determiner] -  Δρ = 0.000009 AU
#
# INFO - [models.orbit_determiner] -  Iteração 5:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: 28539.7072, 28543.0970, 28550.0062 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.000235 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 1.8970 UA, e = 0.1762, i = 1.0805°
# INFO - [core.gauss_iod] -  Velocidade orbital: 21.0 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=1.893157 AU, e=0.188888, i=23.854087°
# INFO - [models.orbit_determiner] -  Δρ = 0.000002 AU
#
# INFO - [models.orbit_determiner] -  Iteração 6:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: 28539.8804, 28543.2702, 28550.1795 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.000235 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 1.8970 UA, e = 0.1762, i = 1.0805°
# INFO - [core.gauss_iod] -  Velocidade orbital: 21.0 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=1.893143 AU, e=0.188718, i=23.854041°
# INFO - [models.orbit_determiner] -  Δρ = 0.000011 AU
#
# INFO - [models.orbit_determiner] -  Iteração 7:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: 28540.1480, 28543.5379, 28550.4472 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.000235 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 1.8970 UA, e = 0.1762, i = 1.0805°
# INFO - [core.gauss_iod] -  Velocidade orbital: 21.0 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=1.893174 AU, e=0.189252, i=23.854172°
# INFO - [models.orbit_determiner] -  Δρ = 0.000010 AU
#
# INFO - [models.orbit_determiner] -  Iteração 8:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: 28537.3981, 28540.7876, 28547.6963 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.000235 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 1.8970 UA, e = 0.1762, i = 1.0805°
# INFO - [core.gauss_iod] -  Velocidade orbital: 21.0 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=1.893139 AU, e=0.188487, i=23.853993°
# INFO - [models.orbit_determiner] -  Δρ = 0.000002 AU
#
# INFO - [models.orbit_determiner] -  Iteração 9:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: 28539.4756, 28542.8654, 28549.7746 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.000235 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 1.8970 UA, e = 0.1762, i = 1.0805°
# INFO - [core.gauss_iod] -  Velocidade orbital: 21.0 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=1.893179 AU, e=0.189282, i=23.854183°
# INFO - [models.orbit_determiner] -  Δρ = 0.000004 AU
#
# INFO - [models.orbit_determiner] -  Iteração 10:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: 28538.7482, 28542.1378, 28549.0469 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.000235 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 1.8970 UA, e = 0.1762, i = 1.0805°
# INFO - [core.gauss_iod] -  Velocidade orbital: 21.0 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=1.893134 AU, e=0.188363, i=23.853964°
# INFO - [models.orbit_determiner] -  Δρ = 0.000003 AU
#
#
# ▶ RESULTADOS
# ────────────
#
#
# ┌──────────────────────────────────┐
# │ ELEMENTOS ORBITAIS PARA 2023 DZ2 │
# ├──────────────────────────────────┤
# │ a: 1.893134 UA                   │
# │ e: 0.188363                      │
# │ i: 0.859069°                     │
# │ Ω: 301.061978°                   │
# │ ω: 79.989474°                    │
# │ θ: 110.716243°                   │
# └──────────────────────────────────┘
#
#
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │ VETOR ESTADO FINAL                                                            │
# ├───────────────────────────────────────────────────────────────────────────────┤
# │ Posição: [-1.30309113  1.34129937  0.5744951 ] (|r| = 1.956317 AU)            │
# │ Velocidade: [-0.01035502 -0.00565588 -0.00264506] (|v| = 0.012092 AU/dia)     │
# │ Resíduo RMS: 0.142 segundos de arco                                           │
# └───────────────────────────────────────────────────────────────────────────────┘
# Comparação com elementos reais (2023 DZ2):
# a real ≈ 2.0820 UA, diferença: 0.1889 UA
# e real ≈ 0.5242, diferença: 0.3358
# i real ≈ 0.15°, diferença: 0.71°

# %%
a, e, i, Omega, omega, theta, r_final, v_final, rms_residuo = determine_orbit("Apophis", observations_apophis)

a_real = 0.9223
e_real = 0.1911
i_real = 3.33
print("\nComparação com elementos reais (Apophis):")
print(f"a real ≈ {a_real:.4f} UA, diferença: {abs(a - a_real):.4f} UA")
print(f"e real ≈ {e_real:.4f}, diferença: {abs(e - e_real):.4f}")
print(f"i real ≈ {i_real:.2f}°, diferença: {abs(i - i_real):.2f}°")
# Out:
# ==================================================
#
# CALCULANDO ÓRBITA DE Apophis USANDO 4 OBSERVAÇÕES
# ==================================================
#
#
# ▶ INICIANDO CORREÇÃO DIFERENCIAL
# ────────────────────────────────
#
# INFO - [models.orbit_determiner] -  Iteração 1:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: -145344.3533, -145325.2753, -145290.4021 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.005006 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 0.7073 UA, e = 0.8792, i = 21.4401°
# INFO - [core.gauss_iod] -  Velocidade orbital: 18.3 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=0.699265 AU, e=0.889661, i=20.626909°
# INFO - [models.orbit_determiner] -  Δρ = 0.000569 AU
#
# INFO - [models.orbit_determiner] -  Iteração 2:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: -145433.0929, -145414.0033, -145379.1088 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.005006 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 0.7074 UA, e = 0.8791, i = 21.4402°
# INFO - [core.gauss_iod] -  Velocidade orbital: 18.3 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=0.699321 AU, e=0.889631, i=20.626145°
# INFO - [models.orbit_determiner] -  Δρ = 0.000003 AU
#
# INFO - [models.orbit_determiner] -  Iteração 3:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: -145433.0942, -145414.0045, -145379.1101 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.005006 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 0.7074 UA, e = 0.8791, i = 21.4402°
# INFO - [core.gauss_iod] -  Velocidade orbital: 18.3 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=0.699323 AU, e=0.889639, i=20.626177°
# INFO - [models.orbit_determiner] -  Δρ = 0.000002 AU
#
# INFO - [models.orbit_determiner] -  Iteração 4:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: -145516.8691, -145497.7684, -145462.8539 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.005006 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 0.7074 UA, e = 0.8791, i = 21.4402°
# INFO - [core.gauss_iod] -  Velocidade orbital: 18.3 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=0.699321 AU, e=0.889635, i=20.626164°
# INFO - [models.orbit_determiner] -  Δρ = 0.000002 AU
#
# INFO - [models.orbit_determiner] -  Iteração 5:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: -145461.0084, -145441.9151, -145407.0140 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.005006 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 0.7074 UA, e = 0.8791, i = 21.4402°
# INFO - [core.gauss_iod] -  Velocidade orbital: 18.3 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=0.699316 AU, e=0.889640, i=20.626233°
# INFO - [models.orbit_determiner] -  Δρ = 0.000005 AU
#
# INFO - [models.orbit_determiner] -  Iteração 6:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: -145498.2440, -145479.1458, -145444.2358 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.005006 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 0.7074 UA, e = 0.8791, i = 21.4402°
# INFO - [core.gauss_iod] -  Velocidade orbital: 18.3 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=0.699319 AU, e=0.889633, i=20.626171°
# INFO - [models.orbit_determiner] -  Δρ = 0.000003 AU
#
# INFO - [models.orbit_determiner] -  Iteração 7:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: -145600.7404, -145581.6288, -145546.6941 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.005006 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 0.7074 UA, e = 0.8791, i = 21.4402°
# INFO - [core.gauss_iod] -  Velocidade orbital: 18.3 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=0.699321 AU, e=0.889640, i=20.626196°
# INFO - [models.orbit_determiner] -  Δρ = 0.000002 AU
#
# INFO - [models.orbit_determiner] -  Iteração 8:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: -145423.7918, -145404.7034, -145369.8112 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.005006 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 0.7074 UA, e = 0.8791, i = 21.4402°
# INFO - [core.gauss_iod] -  Velocidade orbital: 18.3 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=0.699319 AU, e=0.889631, i=20.626154°
# INFO - [models.orbit_determiner] -  Δρ = 0.000002 AU
#
# INFO - [models.orbit_determiner] -  Iteração 9:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: -145386.5943, -145367.5107, -145332.6275 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.005006 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 0.7074 UA, e = 0.8791, i = 21.4402°
# INFO - [core.gauss_iod] -  Velocidade orbital: 18.3 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=0.699323 AU, e=0.889639, i=20.626169°
# INFO - [models.orbit_determiner] -  Δρ = 0.000004 AU
#
# INFO - [models.orbit_determiner] -  Iteração 10:
# WARNING - [core.gauss_iod] -  Observações quase coplanares. Tentando correção...
# INFO - [core.gauss_iod] -  Distâncias calculadas: -145684.7086, -145665.5859, -145630.6311 UA
# INFO - [core.gauss_iod] -  Solução direta produziu distâncias não razoáveis, tentando método iterativo...
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.0000
# INFO - [core.gauss_iod] -  Nova melhor solução encontrada (delta_v = 0.005006 UA/dia)
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 1.5000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.0000
# INFO - [core.gauss_iod] -  Iniciando solução iterativa com rho2_initial = 2.5000
# INFO - [core.gauss_iod] -  Solução pelo método de Gauss: a = 0.7074 UA, e = 0.8791, i = 21.4402°
# INFO - [core.gauss_iod] -  Velocidade orbital: 18.3 km/h
# INFO - [core.gauss_iod] -  Órbita elíptica razoável detectada
# INFO - [core.differential_correction] -  Solução aceita: a=0.699329 AU, e=0.889629, i=20.626070°
# INFO - [models.orbit_determiner] -  Δρ = 0.000005 AU
#
#
# ▶ RESULTADOS
# ────────────
#
#
# ┌─────────────────────────────────┐
# │ ELEMENTOS ORBITAIS PARA Apophis │
# ├─────────────────────────────────┤
# │ a: 0.699329 UA                  │
# │ e: 0.889629                     │
# │ i: 3.449470°                    │
# │ Ω: 214.012709°                  │
# │ ω: 96.954565°                   │
# │ θ: 167.727665°                  │
# └─────────────────────────────────┘
#
#
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │ VETOR ESTADO FINAL                                                            │
# ├───────────────────────────────────────────────────────────────────────────────┤
# │ Posição: [-0.53468133  0.92338895  0.32674054] (|r| = 1.115926 AU)            │
# │ Velocidade: [-0.00924461  0.00446604  0.00134085] (|v| = 0.010354 AU/dia)     │
# │ Resíduo RMS: 1.177 segundos de arco                                           │
# └───────────────────────────────────────────────────────────────────────────────┘
# Comparação com elementos reais (Apophis):
# a real ≈ 0.9223 UA, diferença: 0.2230 UA
# e real ≈ 0.1911, diferença: 0.6985
# i real ≈ 3.33°, diferença: 0.12°
